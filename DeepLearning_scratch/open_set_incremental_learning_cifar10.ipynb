# %%
# --- Load CUDA module (if on HPC) ---
# !module load CUDA/12.6.0

# --- Persist environment variables for this Python process ---
import os

os.environ["CUDA_HOME"] = "/apps/common/software/CUDA/12.6.0"
os.environ["PATH"] = f"{os.environ['CUDA_HOME']}/bin:" + os.environ["PATH"]
os.environ["LD_LIBRARY_PATH"] = f"{os.environ['CUDA_HOME']}/lib64:" + os.environ.get("LD_LIBRARY_PATH", "")

# --- Verify ---
# !which nvcc
# !nvidia-smi
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# /apps/common/software/CUDA/12.6.0/bin/nvcc
# Sun Oct 26 16:05:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          On  |   00000000:4C:00.0 Off |                    0 |
# | N/A   43C    P0             63W /  400W |       1MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          On  |   00000000:CB:00.0 Off |                    0 |
# | N/A   45C    P0             64W /  400W |       1MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# 2025-10-26 16:06:05.331903: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from scipy.stats import entropy

# Load dataset function
def load_data(selected_classes, unknown_class=True):
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    y_train = y_train.flatten()
    y_test = y_test.flatten()

    # Filter known classes
    mask_train = np.isin(y_train, selected_classes)
    mask_test = np.isin(y_test, selected_classes)

    x_train_known, y_train_known = x_train[mask_train], y_train[mask_train]
    x_test_known, y_test_known = x_test[mask_test], y_test[mask_test]

    # Re-map labels to 0-N range
    label_map = {old_label: new_label for new_label, old_label in enumerate(selected_classes)}
    y_train_known = np.vectorize(label_map.get)(y_train_known)
    y_test_known = np.vectorize(label_map.get)(y_test_known)

    # Normalize images
    x_train_known, x_test_known = x_train_known / 255.0, x_test_known / 255.0

    # Add "Unknown" class (samples from other classes)
    if unknown_class:
        unknown_mask_train = ~np.isin(y_train, selected_classes)
        unknown_mask_test = ~np.isin(y_test, selected_classes)

        x_unknown_train, y_unknown_train = x_train[unknown_mask_train], np.full(np.sum(unknown_mask_train), len(selected_classes))
        x_unknown_test, y_unknown_test = x_test[unknown_mask_test], np.full(np.sum(unknown_mask_test), len(selected_classes))

        # Limit the number of unknown samples added
        max_new_unknowns = 3000
        x_unknown_train, y_unknown_train = x_unknown_train[:max_new_unknowns], y_unknown_train[:max_new_unknowns]
        x_unknown_test, y_unknown_test = x_unknown_test[:max_new_unknowns], y_unknown_test[:max_new_unknowns]

        x_train = np.concatenate([x_train_known, x_unknown_train], axis=0)
        y_train = np.concatenate([y_train_known, y_unknown_train], axis=0)
        x_test = np.concatenate([x_test_known, x_unknown_test], axis=0)
        y_test = np.concatenate([y_test_known, y_unknown_test], axis=0)
    else:
        x_train, y_train, x_test, y_test = x_train_known, y_train_known, x_test_known, y_test_known

    # One-hot encode labels
    num_classes = len(selected_classes) + (1 if unknown_class else 0)
    y_train, y_test = to_categorical(y_train, num_classes), to_categorical(y_test, num_classes)

    return x_train, y_train, x_test, y_test, num_classes, label_map

# Detect unknown samples
def detect_unknown_samples(model, x_test, threshold=0.05, entropy_threshold=0.6):
    predictions = model.predict(x_test)
    
    # Extract classification output
    if isinstance(predictions, tuple) or isinstance(predictions, list):
        predictions = predictions[0]

    max_probs = np.max(predictions, axis=1)
    pred_entropy = entropy(predictions.T)

    # Detect unknowns: Low confidence OR high entropy
    unknown_indices = np.where((max_probs < threshold) | (pred_entropy > entropy_threshold))[0]
    return unknown_indices

# Update model to handle new class
def update_model(model, num_classes):
    x = model.layers[-2].output
    new_output = Dense(num_classes, activation="softmax")(x)
    new_model = Model(inputs=model.input, outputs=new_output)
    return new_model

# Train model and detect unknown classes dynamically
def train_and_detect_unknowns():
    known_classes = [0, 1, 2, 3, 4]
    detected_classes = set(known_classes)
    histories = {}
    confusion_matrices = {}

    x_train, y_train, x_test, y_test, num_classes, label_map = load_data(known_classes)

    # Initialize ResNet model
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(256, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax", name="classification_output")(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

    # Train initial model
    print("\n--- Initial Training on Known Classes + Unknown ---")
    history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=64, verbose=1)
    histories["Initial"] = history.history

    # Introduce new classes dynamically
    for new_class in sorted(range(5, 10)):  
        print(f"\n--- Checking for Unknown Samples: Potential Class {new_class} ---")
        
        unknown_indices = detect_unknown_samples(model, x_test)
        print(f"Detected {len(unknown_indices)} unknown samples for potential class {new_class}.")

        if len(unknown_indices) > 50:  # Add new class if threshold met
            print(f"Threshold met! Adding new class {new_class}.")
            detected_classes.add(new_class)
            x_train, y_train, x_test, y_test, num_classes, label_map = load_data(list(detected_classes))

            # Update model with new class
            model = update_model(model, num_classes)
            model.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

            # Train with the new class
            epochs_per_class = {5: 30, 6: 30, 7: 30, 8: 40, 9: 50}
            history = model.fit(x_train, y_train, validation_data=(x_test, y_test), 
                                epochs=epochs_per_class[new_class], batch_size=64, verbose=1)
            histories[f"Class_{new_class}"] = history.history

            # Compute confusion matrix for this class
            y_pred = np.argmax(model.predict(x_test), axis=1)
            y_true = np.argmax(y_test, axis=1)
            cm = confusion_matrix(y_true, y_pred, labels=np.arange(num_classes))
            confusion_matrices[f"Class_{new_class}"] = cm

    return histories, confusion_matrices, list(detected_classes), model, x_test, y_test

# Train model and get final results
histories, confusion_matrices, final_classes, trained_model, final_x_test, final_y_test = train_and_detect_unknowns()

# Plot per-class confusion matrices
for label, cm in confusion_matrices.items():
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f'Confusion Matrix - {label}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# Compute and plot final confusion matrix for all classes
final_predictions = np.argmax(trained_model.predict
I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 16:13:19.740554: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 16:13:19.765660: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-26 16:13:19.901312: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-10-26 16:13:19.959749: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-10-26 16:13:20.002838: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 36 bytes spill stores, 36 bytes spill loads
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step
# Detected 6 unknown samples for potential class 5.
#
# --- Checking for Unknown Samples: Potential Class 6 ---
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Detected 6 unknown samples for potential class 6.
#
# --- Checking for Unknown Samples: Potential Class 7 ---
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Detected 6 unknown samples for potential class 7.
#
# --- Checking for Unknown Samples: Potential Class 8 ---
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Detected 6 unknown samples for potential class 8.
#
# --- Checking for Unknown Samples: Potential Class 9 ---
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Detected 6 unknown samples for potential class 9.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from scipy.stats import entropy
from scipy.spatial.distance import mahalanobis

# -------------------------
# 🔹 Replay Buffer for Balancing Data
# -------------------------
class ReplayBuffer:
    def __init__(self, capacity=3000):
        self.buffer = []
        self.capacity = capacity

    def add_samples(self, x, y):
        if len(self.buffer) >= self.capacity:
            self.buffer = self.buffer[len(y):]  # Remove old samples
        self.buffer.extend(zip(x, y))

    def get_samples(self, batch_size=500):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        samples = [self.buffer[i] for i in indices]
        x_replay, y_replay = zip(*samples)
        return np.array(x_replay), np.array(y_replay)

# -------------------------
# 🔹 Load CIFAR-10 Data
# -------------------------
def load_data(selected_classes, unknown_class=True):
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    y_train = y_train.flatten()
    y_test = y_test.flatten()

    # Filter known classes
    mask_train = np.isin(y_train, selected_classes)
    mask_test = np.isin(y_test, selected_classes)

    x_train_known, y_train_known = x_train[mask_train], y_train[mask_train]
    x_test_known, y_test_known = x_test[mask_test], y_test[mask_test]

    # Re-map labels to 0-N range
    label_map = {old_label: new_label for new_label, old_label in enumerate(selected_classes)}
    y_train_known = np.vectorize(label_map.get)(y_train_known)
    y_test_known = np.vectorize(label_map.get)(y_test_known)

    # Normalize images
    x_train_known, x_test_known = x_train_known / 255.0, x_test_known / 255.0

    # Add "Unknown" class
    if unknown_class:
        unknown_mask_train = ~np.isin(y_train, selected_classes)
        unknown_mask_test = ~np.isin(y_test, selected_classes)

        x_unknown_train, y_unknown_train = x_train[unknown_mask_train], np.full(np.sum(unknown_mask_train), len(selected_classes))
        x_unknown_test, y_unknown_test = x_test[unknown_mask_test], np.full(np.sum(unknown_mask_test), len(selected_classes))

        # Limit the number of unknown samples added
        max_new_unknowns = 3000
        x_unknown_train, y_unknown_train = x_unknown_train[:max_new_unknowns], y_unknown_train[:max_new_unknowns]
        x_unknown_test, y_unknown_test = x_unknown_test[:max_new_unknowns], y_unknown_test[:max_new_unknowns]

        x_train = np.concatenate([x_train_known, x_unknown_train], axis=0)
        y_train = np.concatenate([y_train_known, y_unknown_train], axis=0)
        x_test = np.concatenate([x_test_known, x_unknown_test], axis=0)
        y_test = np.concatenate([y_test_known, y_unknown_test], axis=0)
    else:
        x_train, y_train, x_test, y_test = x_train_known, y_train_known, x_test_known, y_test_known

    # One-hot encode labels
    num_classes = len(selected_classes) + (1 if unknown_class else 0)
    y_train, y_test = to_categorical(y_train, num_classes), to_categorical(y_test, num_classes)

    return x_train, y_train, x_test, y_test, num_classes, label_map

# -------------------------
# 🔹 Detect Unknown Samples
# -------------------------
def detect_unknown_samples(model, x_test, threshold=0.1, entropy_threshold=0.5):
    predictions = model.predict(x_test)
    if isinstance(predictions, tuple) or isinstance(predictions, list):
        predictions = predictions[0]

    max_probs = np.max(predictions, axis=1)
    pred_entropy = entropy(predictions.T)

    # Dynamic thresholding
    softmax_dynamic_threshold = np.percentile(max_probs, 10)
    entropy_dynamic_threshold = np.percentile(pred_entropy, 90)

    # Detect unknowns
    unknown_indices = np.where(
        (max_probs < max(threshold, softmax_dynamic_threshold)) |
        (pred_entropy > min(entropy_threshold, entropy_dynamic_threshold))
    )[0]
    return unknown_indices

# -------------------------
# 🔹 Expand Model for New Class
# -------------------------
def expand_model(model, num_classes):
    for layer in model.layers[:-2]:
        layer.trainable = False

    x = model.layers[-2].output
    new_output = Dense(num_classes, activation="softmax")(x)
    new_model = Model(inputs=model.input, outputs=new_output)

    return new_model

# -------------------------
# 🔹 Train Model and Detect Unknown Classes
# -------------------------
def train_and_detect_unknowns():
    known_classes = [0, 1, 2, 3, 4]
    detected_classes = set(known_classes)
    histories = {}
    confusion_matrices = {}

    x_train, y_train, x_test, y_test, num_classes, label_map = load_data(known_classes)
    replay_buffer = ReplayBuffer()

    # Initialize ResNet model
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(256, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

    # Initial training
    print("\n--- Initial Training on Known Classes + Unknown ---")
    history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=64, verbose=1)
    histories["Initial"] = history.history

    for new_class in range(5, 10):
        print(f"\n--- Checking for Unknown Samples: Potential Class {new_class} ---")

        unknown_indices = detect_unknown_samples(model, x_test)
        print(f"Detected {len(unknown_indices)} unknown samples for class {new_class}.")

        if len(unknown_indices) > 50:
            print(f"Threshold met! Adding new class {new_class}.")
            detected_classes.add(new_class)
            x_train, y_train, x_test, y_test, num_classes, label_map = load_data(list(detected_classes))

            # Update model
            model = expand_model(model, num_classes)
            model.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

            # Train model with new class
            history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, batch_size=64, verbose=1)
            histories[f"Class_{new_class}"] = history.history

    return histories, model, x_test, y_test

# -------------------------
# 🔹 Train & Evaluate Model
# -------------------------
histories, trained_model, final_x_test, final_y_test = train_and_detect_unknowns()

# Compute final confusion matrix
final_predictions = np.argmax(trained_model.predict(final_x_test), axis=1)
final_true_labels = np.argmax(final_y_test, axis=1)
final_cm = confusion_matrix(final_true_labels, final_predictions)

plt.figure(figsize=(10, 8))
sns.heatmap(final_cm, annot=True, fmt=".2f", cmap="Blues")
plt.title("Final Confusion Matrix - All Classes")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# --- Initial Training on Known Classes + Unknown ---
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.2816 - loss: 1.5705 - val_accuracy: 0.5000 - val_loss: 1.0499
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.2862 - loss: 1.4684 - val_accuracy: 0.5000 - val_loss: 1.0138
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.2842 - loss: 1.4444 - val_accuracy: 0.5000 - val_loss: 1.0090
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.2822 - loss: 1.4409 - val_accuracy: 0.5000 - val_loss: 1.0074
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.4145 - loss: 1.2547 - val_accuracy: 0.5863 - val_loss: 1.3383
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.6208 - loss: 0.8878 - val_accuracy: 0.6012 - val_loss: 3.3934
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.7273 - loss: 0.7324 - val_accuracy: 0.6171 - val_loss: 0.9539
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.7550 - loss: 0.6660 - val_accuracy: 0.5636 - val_loss: 2.1770
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.7660 - loss: 0.6299 - val_accuracy: 0.5044 - val_loss: 3.1716
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.7806 - loss: 0.5960 - val_accuracy: 0.5962 - val_loss: 2.3292
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.7844 - loss: 0.5804 - val_accuracy: 0.6684 - val_loss: 1.7272
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.7909 - loss: 0.5586 - val_accuracy: 0.5671 - val_loss: 3.2645
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.8017 - loss: 0.5459 - val_accuracy: 0.6649 - val_loss: 1.4514
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.8092 - loss: 0.5126 - val_accuracy: 0.5086 - val_loss: 3.2004
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.8152 - loss: 0.4988 - val_accuracy: 0.6475 - val_loss: 1.0331
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.8222 - loss: 0.4787 - val_accuracy: 0.7125 - val_loss: 0.7157
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.8316 - loss: 0.4695 - val_accuracy: 0.5700 - val_loss: 1.6547
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.8348 - loss: 0.4605 - val_accuracy: 0.5810 - val_loss: 1.0461
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.8441 - loss: 0.4172 - val_accuracy: 0.6691 - val_loss: 1.3742
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.8523 - loss: 0.3976 - val_accuracy: 0.5362 - val_loss: 3.3564
#
# --- Checking for Unknown Samples: Potential Class 5 ---
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Detected 933 unknown samples for class 5.
# Threshold met! Adding new class 5.
# Epoch 1/30
# 510/516 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4149 - loss: 1.5658
# 2025-10-26 16:20:14.972233: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 16:20:14.972314: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 16:20:15.175019: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5022', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 16:20:15.667652: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5627', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-10-26 16:20:15.667690: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5367', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-10-26 16:20:15.800826: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5367', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 16:20:15.800882: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5627', 164 bytes spill stores, 164 bytes spill loads
#
# 2025-10-26 16:20:15.827774: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5367', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-10-26 16:20:15.827827: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5367', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-10-26 16:20:15.834738: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5627', 492 bytes spill stores, 492 bytes spill loads
#
# 2025-10-26 16:20:16.242678: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5627', 580 bytes spill stores, 580 bytes spill loads
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4161 - loss: 1.5618
# 2025-10-26 16:20:25.789424: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 16:20:26.044289: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 16:20:26.252752: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 16:20:26.252791: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-26 16:20:26.311566: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-10-26 16:20:26.401773: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-10-26 16:20:26.485493: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-10-26 16:20:26.550615: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1749', 36 bytes spill stores, 36 bytes spill loads
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 28s 38ms/step - accuracy: 0.5163 - loss: 1.2210 - val_accuracy: 0.7329 - val_loss: 0.6951
# Epoch 2/30
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6250 - loss: 0.9382 - val_accuracy: 0.7474 - val_loss: 0.6500
# Epoch 3/30
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6463 - loss: 0.8891 - val_accuracy: 0.7434 - val_loss: 0.6367
# Epoch 4/30
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.4734 - loss: 1.4082 - val_accuracy: 0.5159 - val_loss: 1.3412
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.4811 - loss: 1.3834 - val_accuracy: 0.5188 - val_loss: 1.3315
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4899 - loss: 1.3672 - val_accuracy: 0.5194 - val_loss: 1.3215
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4928 - loss: 1.3569 - val_accuracy: 0.5330 - val_loss: 1.3011
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.4975 - loss: 1.3477 - val_accuracy: 0.5356 - val_loss: 1.2958
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4994 - loss: 1.3440 - val_accuracy: 0.5278 - val_loss: 1.2965
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5018 - loss: 1.3358 - val_accuracy: 0.5334 - val_loss: 1.2908
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5031 - loss: 1.3345 - val_accuracy: 0.5415 - val_loss: 1.2788
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5025 - loss: 1.3310 - val_accuracy: 0.5326 - val_loss: 1.2800
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5071 - loss: 1.3223 - val_accuracy: 0.5420 - val_loss: 1.2746
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5057 - loss: 1.3228 - val_accuracy: 0.5376 - val_loss: 1.2773
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5058 - loss: 1.3190 - val_accuracy: 0.5364 - val_loss: 1.2800
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5096 - loss: 1.3165 - val_accuracy: 0.5387 - val_loss: 1.2743
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5099 - loss: 1.3183 - val_accuracy: 0.5401 - val_loss: 1.2737
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5119 - loss: 1.3144 - val_accuracy: 0.5468 - val_loss: 1.2626
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5099 - loss: 1.3118 - val_accuracy: 0.5400 - val_loss: 1.2645
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5111 - loss: 1.3058 - val_accuracy: 0.5469 - val_loss: 1.2593
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5127 - loss: 1.3063 - val_accuracy: 0.5453 - val_loss: 1.2565
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5133 - loss: 1.3080 - val_accuracy: 0.5439 - val_loss: 1.2559
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5123 - loss: 1.3046 - val_accuracy: 0.5431 - val_loss: 1.2575
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5139 - loss: 1.3049 - val_accuracy: 0.5463 - val_loss: 1.2552
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5125 - loss: 1.3035 - val_accuracy: 0.5481 - val_loss: 1.2550
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5169 - loss: 1.2983 - val_accuracy: 0.5477 - val_loss: 1.2555
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5149 - loss: 1.3008 - val_accuracy: 0.5501 - val_loss: 1.2507
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5156 - loss: 1.2950 - val_accuracy: 0.5448 - val_loss: 1.2502
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5159 - loss: 1.2977 - val_accuracy: 0.5466 - val_loss: 1.2482
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5171 - loss: 1.2960 - val_accuracy: 0.5553 - val_loss: 1.2447
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5168 - loss: 1.2958 - val_accuracy: 0.5517 - val_loss: 1.2455
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from scipy.stats import entropy

# -------------------------
# 🔹 Replay Buffer for Balancing Data
# -------------------------
class ReplayBuffer:
    def __init__(self, capacity=3000):
        self.buffer = []
        self.capacity = capacity

    def add_samples(self, x, y):
        if len(self.buffer) >= self.capacity:
            self.buffer = self.buffer[len(y):]  # Remove old samples
        self.buffer.extend(zip(x, y))

    def get_samples(self, batch_size=500):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        samples = [self.buffer[i] for i in indices]
        x_replay, y_replay = zip(*samples)
        return np.array(x_replay), np.array(y_replay)

# -------------------------
# 🔹 Load CIFAR-10 Data
# -------------------------
def load_data(selected_classes, unknown_class=True):
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    y_train = y_train.flatten()
    y_test = y_test.flatten()

    # Filter known classes
    mask_train = np.isin(y_train, selected_classes)
    mask_test = np.isin(y_test, selected_classes)

    x_train_known, y_train_known = x_train[mask_train], y_train[mask_train]
    x_test_known, y_test_known = x_test[mask_test], y_test[mask_test]

    # Re-map labels to 0-N range
    label_map = {old_label: new_label for new_label, old_label in enumerate(selected_classes)}
    y_train_known = np.vectorize(label_map.get)(y_train_known)
    y_test_known = np.vectorize(label_map.get)(y_test_known)

    # Normalize images
    x_train_known, x_test_known = x_train_known / 255.0, x_test_known / 255.0

    # Add "Unknown" class
    if unknown_class:
        unknown_mask_train = ~np.isin(y_train, selected_classes)
        unknown_mask_test = ~np.isin(y_test, selected_classes)

        x_unknown_train, y_unknown_train = x_train[unknown_mask_train], np.full(np.sum(unknown_mask_train), len(selected_classes))
        x_unknown_test, y_unknown_test = x_test[unknown_mask_test], np.full(np.sum(unknown_mask_test), len(selected_classes))

        # Limit the number of unknown samples added
        max_new_unknowns = 3000
        x_unknown_train, y_unknown_train = x_unknown_train[:max_new_unknowns], y_unknown_train[:max_new_unknowns]
        x_unknown_test, y_unknown_test = x_unknown_test[:max_new_unknowns], y_unknown_test[:max_new_unknowns]

        x_train = np.concatenate([x_train_known, x_unknown_train], axis=0)
        y_train = np.concatenate([y_train_known, y_unknown_train], axis=0)
        x_test = np.concatenate([x_test_known, x_unknown_test], axis=0)
        y_test = np.concatenate([y_test_known, y_unknown_test], axis=0)
    else:
        x_train, y_train, x_test, y_test = x_train_known, y_train_known, x_test_known, y_test_known

    # One-hot encode labels
    num_classes = len(selected_classes) + (1 if unknown_class else 0)
    y_train, y_test = to_categorical(y_train, num_classes), to_categorical(y_test, num_classes)

    return x_train, y_train, x_test, y_test, num_classes, label_map

# -------------------------
# 🔹 Improve Model Fine-Tuning (Replay Buffer & Knowledge Distillation)
# -------------------------
def fine_tune_model(trained_model, x_train, y_train, x_test, y_test):
    # Learning rate decay
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=1e-4,
        decay_steps=10000,
        decay_rate=0.9
    )
    optimizer = Adam(learning_rate=lr_schedule)

    trained_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

    print("\n--- Fine-Tuning Model with All Classes ---")
    history_finetune = trained_model.fit(x_train, y_train, validation_data=(x_test, y_test),
                                         epochs=30, batch_size=64, verbose=1)
    return history_finetune

# -------------------------
# 🔹 Final Training Setup
# -------------------------
def train_final_model():
    final_classes = list(range(10))  # All CIFAR-10 classes
    x_train, y_train, x_test, y_test, num_classes, label_map = load_data(final_classes, unknown_class=False)

    # Initialize ResNet model
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(256, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

    # Train the final model
    print("\n--- Initial Training on All Classes ---")
    history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, batch_size=64, verbose=1)

    return model, x_test, y_test

# -------------------------
# 🔹 Train and Evaluate Final Model
# -------------------------
trained_model, final_x_test, final_y_test = train_final_model()

# Fine-tune the model further
fine_tune_model(trained_model, final_x_test, final_y_test, final_x_test, final_y_test)

# Compute final confusion matrix
final_predictions = np.argmax(trained_model.predict(final_x_test), axis=1)
final_true_labels = np.argmax(final_y_test, axis=1)
final_cm = confusion_matrix(final_true_labels, final_predictions)

# -------------------------
# 🔹 Plot Normalized Confusion Matrix
# -------------------------
def plot_confusion_matrix(cm, labels):
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)
    plt.title("Final Normalized Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

plot_confusion_matrix(final_cm, list(range(10)))
# Out:
# --- Initial Training on All Classes ---
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 69ms/step - accuracy: 0.5300 - loss: 1.3857 - val_accuracy: 0.3080 - val_loss: 2.2647
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.7417 - loss: 0.7694 - val_accuracy: 0.7726 - val_loss: 0.6812
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8122 - loss: 0.5578 - val_accuracy: 0.7826 - val_loss: 0.6610
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8581 - loss: 0.4227 - val_accuracy: 0.7888 - val_loss: 0.6756
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8915 - loss: 0.3224 - val_accuracy: 0.8031 - val_loss: 0.6627
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9190 - loss: 0.2446 - val_accuracy: 0.7971 - val_loss: 0.7145
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9302 - loss: 0.2085 - val_accuracy: 0.8035 - val_loss: 0.7622
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9480 - loss: 0.1557 - val_accuracy: 0.8079 - val_loss: 0.7646
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9563 - loss: 0.1326 - val_accuracy: 0.8091 - val_loss: 0.7922
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9629 - loss: 0.1174 - val_accuracy: 0.8121 - val_loss: 0.7817
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9642 - loss: 0.1070 - val_accuracy: 0.8110 - val_loss: 0.8273
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9687 - loss: 0.0948 - val_accuracy: 0.8153 - val_loss: 0.8229
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9727 - loss: 0.0851 - val_accuracy: 0.8144 - val_loss: 0.8347
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9750 - loss: 0.0759 - val_accuracy: 0.8134 - val_loss: 0.9014
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9769 - loss: 0.0708 - val_accuracy: 0.8134 - val_loss: 0.8347
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9795 - loss: 0.0648 - val_accuracy: 0.8178 - val_loss: 0.8677
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9813 - loss: 0.0588 - val_accuracy: 0.8127 - val_loss: 0.9065
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9797 - loss: 0.0646 - val_accuracy: 0.8197 - val_loss: 0.8702
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9805 - loss: 0.0596 - val_accuracy: 0.8153 - val_loss: 0.8877
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9834 - loss: 0.0516 - val_accuracy: 0.8139 - val_loss: 0.9305
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9819 - loss: 0.0558 - val_accuracy: 0.8221 - val_loss: 0.9216
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9851 - loss: 0.0474 - val_accuracy: 0.8188 - val_loss: 0.9008
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9869 - loss: 0.0400 - val_accuracy: 0.8156 - val_loss: 0.9208
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9858 - loss: 0.0439 - val_accuracy: 0.8211 - val_loss: 0.8843
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9856 - loss: 0.0461 - val_accuracy: 0.8154 - val_loss: 0.9700
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9861 - loss: 0.0446 - val_accuracy: 0.8172 - val_loss: 0.9564
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.9871 - loss: 0.0403 - val_accuracy: 0.8160 - val_loss: 0.9328
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9861 - loss: 0.0450 - val_accuracy: 0.8170 - val_loss: 0.9860
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9890 - loss: 0.0346 - val_accuracy: 0.8276 - val_loss: 0.9318
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.9901 - loss: 0.0320 - val_accuracy: 0.8202 - val_loss: 0.9602
#
# --- Fine-Tuning Model with All Classes ---
# Epoch 1/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 67s 186ms/step - accuracy: 0.8163 - loss: 0.6174 - val_accuracy: 0.9315 - val_loss: 0.2160
# Epoch 2/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9231 - loss: 0.2547 - val_accuracy: 0.9786 - val_loss: 0.0910
# Epoch 3/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9639 - loss: 0.1235 - val_accuracy: 0.9925 - val_loss: 0.0308
# Epoch 4/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9852 - loss: 0.0521 - val_accuracy: 0.9956 - val_loss: 0.0164
# Epoch 5/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9903 - loss: 0.0346 - val_accuracy: 0.9963 - val_loss: 0.0112
# Epoch 6/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9893 - loss: 0.0350 - val_accuracy: 0.9973 - val_loss: 0.0112
# Epoch 7/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9907 - loss: 0.0306 - val_accuracy: 0.9951 - val_loss: 0.0152
# Epoch 8/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.9854 - loss: 0.0471 - val_accuracy: 0.9945 - val_loss: 0.0164
# Epoch 9/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9885 - loss: 0.0394 - val_accuracy: 0.9960 - val_loss: 0.0149
# Epoch 10/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9913 - loss: 0.0254 - val_accuracy: 0.9972 - val_loss: 0.0098
# Epoch 11/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9937 - loss: 0.0210 - val_accuracy: 0.9982 - val_loss: 0.0055
# Epoch 12/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9899 - loss: 0.0337 - val_accuracy: 0.9971 - val_loss: 0.0109
# Epoch 13/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.9930 - loss: 0.0250 - val_accuracy: 0.9972 - val_loss: 0.0111
# Epoch 14/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9883 - loss: 0.0372 - val_accuracy: 0.9977 - val_loss: 0.0062
# Epoch 15/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9910 - loss: 0.0253 - val_accuracy: 0.9977 - val_loss: 0.0093
# Epoch 16/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9890 - loss: 0.0326 - val_accuracy: 0.9965 - val_loss: 0.0104
# Epoch 17/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9946 - loss: 0.0175 - val_accuracy: 0.9992 - val_loss: 0.0031
# Epoch 18/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.9972 - loss: 0.0106 - val_accuracy: 0.9996 - val_loss: 0.0012
# Epoch 19/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9967 - loss: 0.0116 - val_accuracy: 0.9977 - val_loss: 0.0069
# Epoch 20/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9942 - loss: 0.0165 - val_accuracy: 0.9986 - val_loss: 0.0048
# Epoch 21/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9925 - loss: 0.0222 - val_accuracy: 0.9963 - val_loss: 0.0090
# Epoch 22/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9913 - loss: 0.0281 - val_accuracy: 0.9970 - val_loss: 0.0087
# Epoch 23/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9935 - loss: 0.0182 - val_accuracy: 0.9980 - val_loss: 0.0065
# Epoch 24/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9955 - loss: 0.0149 - val_accuracy: 0.9994 - val_loss: 0.0019
# Epoch 25/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9928 - loss: 0.0257 - val_accuracy: 0.9978 - val_loss: 0.0081
# Epoch 26/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.9914 - loss: 0.0357 - val_accuracy: 0.9459 - val_loss: 0.2165
# Epoch 27/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9913 - loss: 0.0310 - val_accuracy: 0.9974 - val_loss: 0.0087
# Epoch 28/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9869 - loss: 0.0435 - val_accuracy: 0.9978 - val_loss: 0.0093
# Epoch 29/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9957 - loss: 0.0160 - val_accuracy: 0.9984 - val_loss: 0.0058
# Epoch 30/30
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.9979 - loss: 0.0095 - val_accuracy: 0.9995 - val_loss: 0.0017
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step

# %%
import random
import matplotlib.pyplot as plt

# CIFAR-10 class labels
cifar10_labels = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

# Select random samples
num_samples = 10  # Number of images to display
indices = random.sample(range(len(final_x_test)), num_samples)
sample_images = final_x_test[indices]
true_labels = np.argmax(final_y_test[indices], axis=1)
predicted_labels = np.argmax(trained_model.predict(sample_images), axis=1)

# Plot images with predictions
fig, axes = plt.subplots(2, 5, figsize=(12, 6))

for i, ax in enumerate(axes.flat):
    img = sample_images[i]
    true_label = cifar10_labels[true_labels[i]]
    predicted_label = cifar10_labels[predicted_labels[i]]

    ax.imshow(img)
    ax.set_title(f"True: {true_label}\nPred: {predicted_label}", fontsize=10)
    ax.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 2025-10-26 17:01:55.943625: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1685', 8 bytes spill stores, 8 bytes spill loads
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
