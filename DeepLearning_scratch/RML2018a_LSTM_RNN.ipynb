# %%
# ==============================================================
# LSTM-RNN From Scratch for RML2018.01A Dataset (24 Classes)
# ==============================================================

import h5py, ast, numpy as np, tensorflow as tf, matplotlib.pyplot as plt, seaborn as sns
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# -------------------- Parameters --------------------
SNR_RANGE = (12, 20)
MAX_SAMPLES_PER_CLASS = 3000
EPOCHS = 250
BATCH_SIZE = 64
LR = 1e-4

# -------------------- Load Data ---------------------
def load_rml2018(h5_path, classes_txt, snr_range=(12,20)):
    with open(classes_txt, "r") as f:
        class_list = ast.literal_eval(f.read().split("=")[-1].strip())
        class_list = [c.strip(" '") for c in class_list]

    with h5py.File(h5_path, "r") as f:
        X, Y, Z = f["X"][:], f["Y"][:], f["Z"][:]

    per_class = {cls: [] for cls in class_list}
    for i in range(len(X)):
        snr = int(Z[i][0])
        if snr_range[0] <= snr <= snr_range[1]:
            label_idx = int(Y[i].argmax())
            cls = class_list[label_idx]
            sig = np.hstack([X[i], np.full((1024,1), snr, dtype=np.float32)])  # shape (1024, 3)
            per_class[cls].append(sig)

    # Trim to max per class
    for k in per_class:
        per_class[k] = per_class[k][:MAX_SAMPLES_PER_CLASS]

    return per_class

data = load_rml2018("RML2018/2018.01/GOLD_XYZ_OSC.0001_1024.hdf5", "RML2018/2018.01/classes.txt")

# -------------------- Prepare Dataset ---------------------
X, y = [], []
for cls, samples in data.items():
    X.extend(samples)
    y.extend([cls] * len(samples))

X = np.array(X, dtype=np.float32)
y = np.array(y)

le = LabelEncoder()
y_enc = le.fit_transform(y)
n_classes = len(le.classes_)
print("Classes:", le.classes_)

# -------------------- Split Dataset ---------------------
X_tr, X_te, y_tr, y_te = train_test_split(
    X, y_enc, test_size=0.2, stratify=y_enc, random_state=42
)
print("Train/Test split:", X_tr.shape, X_te.shape)

# -------------------- Build Model ---------------------
def build_model(input_shape, n_classes, lr=1e-4):
    model = Sequential([
        LSTM(128, input_shape=input_shape, return_sequences=True),
        Dropout(0.5),
        LSTM(128, return_sequences=False),
        Dropout(0.2),
        Dense(128, activation="relu"),
        Dropout(0.1),
        Dense(n_classes, activation="softmax")
    ])
    model.compile(
        optimizer=Adam(lr),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

model = build_model((1024, 3), n_classes, LR)
model.summary()

# -------------------- Train Model ---------------------
history = model.fit(
    X_tr, y_tr,
    validation_data=(X_te, y_te),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2
)

# -------------------- Evaluate ---------------------
y_prob = model.predict(X_te, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

print("\nClassification Report:")
print(classification_report(y_te, y_pred, target_names=le.classes_))

cm = confusion_matrix(y_te, y_pred)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=False, cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix – RML2018 (24 Classes)")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# 2025-05-06 17:15:58.125873: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-06 17:15:58.141666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746566158.155004  798909 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746566158.158949  798909 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 17:15:58.173501: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Classes: ['128APSK' '128QAM' '16APSK' '16PSK' '16QAM' '256QAM' '32APSK' '32PSK'
#  '32QAM' '4ASK' '64APSK' '64QAM' '8ASK' '8PSK' 'AM-DSB-SC' 'AM-DSB-WC'
#  'AM-SSB-SC' 'AM-SSB-WC' 'BPSK' 'FM' 'GMSK' 'OOK' 'OQPSK' 'QPSK']
# Train/Test split: (57600, 1024, 3) (14400, 1024, 3)
# I0000 00:00:1746566191.506053  798909 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22280 MB memory:  -> device: 0, name: NVIDIA A30, pci bus id: 0000:ca:00.0, compute capability: 8.0
# /apps/easybuild/software/falcon-sapphirerapids/Python/3.11.5-GCCcore-13.2.0/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1024, 128)      │        67,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 218,776 (854.59 KB)
#  Trainable params: 218,776 (854.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# I0000 00:00:1746566193.940394  799193 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 900/900 - 59s - 65ms/step - accuracy: 0.1062 - loss: 2.8367 - val_accuracy: 0.1528 - val_loss: 2.5555
# Epoch 2/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1426 - loss: 2.5993 - val_accuracy: 0.1640 - val_loss: 2.5100
# Epoch 3/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1595 - loss: 2.5454 - val_accuracy: 0.1891 - val_loss: 2.4912
# Epoch 4/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1481 - loss: 2.5741 - val_accuracy: 0.1686 - val_loss: 2.5074
# Epoch 5/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1613 - loss: 2.5349 - val_accuracy: 0.2167 - val_loss: 2.4717
# Epoch 6/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1612 - loss: 2.5370 - val_accuracy: 0.1594 - val_loss: 2.5093
# Epoch 7/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1571 - loss: 2.5552 - val_accuracy: 0.1562 - val_loss: 2.5155
# Epoch 8/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1637 - loss: 2.5305 - val_accuracy: 0.1413 - val_loss: 2.6644
# Epoch 9/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1560 - loss: 2.5505 - val_accuracy: 0.1708 - val_loss: 2.5090
# Epoch 10/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1719 - loss: 2.5024 - val_accuracy: 0.1867 - val_loss: 2.4655
# Epoch 11/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1422 - loss: 2.6916 - val_accuracy: 0.1394 - val_loss: 2.6693
# Epoch 12/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1412 - loss: 2.6521 - val_accuracy: 0.1515 - val_loss: 2.6150
# Epoch 13/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1486 - loss: 2.6063 - val_accuracy: 0.1628 - val_loss: 2.5456
# Epoch 14/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1590 - loss: 2.5452 - val_accuracy: 0.1637 - val_loss: 2.5168
# Epoch 15/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1512 - loss: 2.5862 - val_accuracy: 0.1610 - val_loss: 2.5090
# Epoch 16/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1613 - loss: 2.5306 - val_accuracy: 0.1690 - val_loss: 2.5182
# Epoch 17/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1724 - loss: 2.5038 - val_accuracy: 0.1781 - val_loss: 2.4891
# Epoch 18/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1870 - loss: 2.4723 - val_accuracy: 0.1782 - val_loss: 2.5066
# Epoch 19/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1709 - loss: 2.5114 - val_accuracy: 0.1819 - val_loss: 2.4783
# Epoch 20/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1718 - loss: 2.5125 - val_accuracy: 0.1791 - val_loss: 2.4838
# Epoch 21/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1732 - loss: 2.4923 - val_accuracy: 0.1993 - val_loss: 2.4514
# Epoch 22/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1761 - loss: 2.4945 - val_accuracy: 0.1545 - val_loss: 2.5539
# Epoch 23/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1728 - loss: 2.5007 - val_accuracy: 0.1786 - val_loss: 2.5020
# Epoch 24/150
# 900/900 - 56s - 62ms/step - accuracy: 0.2013 - loss: 2.2876 - val_accuracy: 0.2089 - val_loss: 2.1703
# Epoch 25/150
# 900/900 - 56s - 62ms/step - accuracy: 0.2108 - loss: 2.1999 - val_accuracy: 0.2311 - val_loss: 2.1379
# Epoch 26/150
# 900/900 - 56s - 62ms/step - accuracy: 0.2052 - loss: 2.1941 - val_accuracy: 0.2172 - val_loss: 2.1428
# Epoch 27/150
# 900/900 - 56s - 62ms/step - accuracy: 0.2021 - loss: 2.3820 - val_accuracy: 0.1886 - val_loss: 2.2224
# Epoch 28/150
# 900/900 - 56s - 62ms/step - accuracy: 0.2260 - loss: 2.1731 - val_accuracy: 0.2354 - val_loss: 2.1257
# Epoch 29/150
# 900/900 - 56s - 62ms/step - accuracy: 0.1846 - loss: 2.5070 - val_accuracy: 0.1433 - val_loss: 2.6482
# Epoch 30/150
# 900/900 - 56s - 62ms/step - accuracy: 0.
#         8ASK       0.00      0.00      0.00       600
#         8PSK       1.00      0.97      0.98       600
#    AM-DSB-SC       0.43      0.37      0.40       600
#    AM-DSB-WC       1.00      1.00      1.00       600
#    AM-SSB-SC       0.57      0.84      0.68       600
#    AM-SSB-WC       0.85      0.48      0.61       600
#         BPSK       0.99      0.99      0.99       600
#           FM       1.00      1.00      1.00       600
#         GMSK       0.98      0.99      0.99       600
#          OOK       1.00      1.00      1.00       600
#        OQPSK       0.37      0.34      0.35       600
#         QPSK       0.86      0.99      0.92       600
#
#     accuracy                           0.74     14400
#    macro avg       0.73      0.74      0.73     14400
# weighted avg       0.73      0.74      0.73     14400
# /home/rameyjm7/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/rameyjm7/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/rameyjm7/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import h5py, ast, numpy as np, tensorflow as tf, matplotlib.pyplot as plt, seaborn as sns, random
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# -------------------- Parameters --------------------
MAX_SAMPLES_PER_CLASS = 3000
EPOCHS = 250
BATCH_SIZE = 64
LR = 1e-4
SNR_CUTOFF = -6  # Change to e.g. -6 to filter by minimum SNR
EXPORT_MODEL_PATH = "rml2018_lstm_model.keras"
H5_PATH = "RML2018/2018.01/GOLD_XYZ_OSC.0001_1024.hdf5"
CLASSES_PATH = "RML2018/2018.01/classes.txt"

# -------------------- Load Dataset ---------------------
def load_rml2018_balanced(h5_path, classes_txt, max_per_class=3000, snr_cutoff=None):
    with open(classes_txt, "r") as f:
        class_list = ast.literal_eval(f.read().split("=")[-1].strip())
        class_list = [c.strip(" '") for c in class_list]

    with h5py.File(h5_path, "r") as f:
        X, Y, Z = f["X"][:], f["Y"][:], f["Z"][:]

    per_class = {cls: [] for cls in class_list}
    for i in range(len(X)):
        snr = int(Z[i][0])
        if snr_cutoff is None or snr >= snr_cutoff:
            label_idx = int(Y[i].argmax())
            cls = class_list[label_idx]
            sig = np.hstack([X[i], np.full((1024, 1), snr, dtype=np.float32)])
            per_class[cls].append((sig, snr))

    for k in per_class:
        random.shuffle(per_class[k])
        per_class[k] = per_class[k][:max_per_class]

    X, y, snrs = [], [], []
    for cls, samples in per_class.items():
        for sig, snr in samples:
            X.append(sig)
            y.append(cls)
            snrs.append(snr)

    return np.array(X, dtype=np.float32), np.array(y), np.array(snrs), class_list

X_all, y_all, snrs_all, class_list = load_rml2018_balanced(
    H5_PATH, CLASSES_PATH, MAX_SAMPLES_PER_CLASS, SNR_CUTOFF
)

# -------------------- Encode Labels ---------------------
le = LabelEncoder()
y_all_enc = le.fit_transform(y_all)
n_classes = len(le.classes_)
print(f"Classes ({n_classes}):", le.classes_)

# -------------------- Train/Val Split ---------------------
X_tr, X_val, y_tr, y_val = train_test_split(
    X_all, y_all_enc, test_size=0.2, stratify=y_all_enc, random_state=42
)

# -------------------- Build LSTM Model ---------------------
def build_model(input_shape, n_classes, lr=1e-4):
    model = Sequential([
        LSTM(128, input_shape=input_shape, return_sequences=True),
        Dropout(0.5),
        LSTM(128, return_sequences=False),
        Dropout(0.2),
        Dense(128, activation="relu"),
        Dropout(0.1),
        Dense(n_classes, activation="softmax")
    ])
    model.compile(
        optimizer=Adam(lr),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

model = build_model((1024, 3), n_classes, LR)
model.summary()

# -------------------- Train Model ---------------------
history = model.fit(
    X_tr, y_tr,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2
)

# -------------------- Plot Accuracy ---------------------
plt.figure(figsize=(7, 5))
plt.plot(history.history["accuracy"], label="Train Acc")
plt.plot(history.history["val_accuracy"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training & Validation Accuracy (250 Epochs)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# -------------------- Evaluate All ---------------------
y_prob = model.predict(X_all, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

print("\nClassification Report (All SNRs):")
print(classification_report(y_all_enc, y_pred, target_names=le.classes_))

cm = confusion_matrix(y_all_enc, y_pred)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=False, cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix – RML2018a")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# -------------------- Accuracy per SNR ---------------------
snr_unique = sorted(np.unique(snrs_all))
acc_per_snr = []
for snr in snr_unique:
    idx = np.where(snrs_all == snr)[0]
    acc = np.mean(y_pred[idx] == y_all_enc[idx])
    acc_per_snr.append(acc)

plt.figure(figsize=(8, 5))
plt.plot(snr_unique, acc_per_snr, marker="o")
plt.title("Accuracy vs SNR")
plt.xlabel("SNR [dB]")
plt.ylabel("Accuracy")
plt.grid(True)
plt.tight_layout()
plt.show()

# -------------------- Save Model ---------------------
model.save(EXPORT_MODEL_PATH)
print(f"\n✅ Model saved to {EXPORT_MODEL_PATH}")
# Out:
# 2025-05-07 11:29:30.259397: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-07 11:29:30.274882: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746631770.288005 2470775 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746631770.291890 2470775 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-07 11:29:30.305663: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Classes (24): ['128APSK' '128QAM' '16APSK' '16PSK' '16QAM' '256QAM' '32APSK' '32PSK'
#  '32QAM' '4ASK' '64APSK' '64QAM' '8ASK' '8PSK' 'AM-DSB-SC' 'AM-DSB-WC'
#  'AM-SSB-SC' 'AM-SSB-WC' 'BPSK' 'FM' 'GMSK' 'OOK' 'OQPSK' 'QPSK']
# I0000 00:00:1746631824.650249 2470775 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22280 MB memory:  -> device: 0, name: NVIDIA A30, pci bus id: 0000:4a:00.0, compute capability: 8.0
# /apps/easybuild/software/falcon-sapphirerapids/Python/3.11.5-GCCcore-13.2.0/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1024, 128)      │        67,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 218,776 (854.59 KB)
#  Trainable params: 218,776 (854.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/250
# I0000 00:00:1746631827.731024 2471063 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 900/900 - 59s - 66ms/step - accuracy: 0.0739 - loss: 3.0220 - val_accuracy: 0.1061 - val_loss: 2.9021
# Epoch 2/250
# 900/900 - 56s - 62ms/step - accuracy: 0.0948 - loss: 2.8714 - val_accuracy: 0.1211 - val_loss: 2.6967
# Epoch 3/250
# 900/900 - 56s - 62ms/step - accuracy: 0.1062 - loss: 2.7840 - val_accuracy: 0.0796 - val_loss: 2.9894
# Epoch 4/250
# 900/900 - 56s - 62ms/step - accuracy: 0.0948 - loss: 2.8769 - val_accuracy: 0.1089 - val_loss: 2.7496
# Epoch 5/250
# 900/900 - 56s - 62ms/step - accuracy: 0.1151 - loss: 2.7241 - val_accuracy: 0.1361 - val_loss: 2.6359
# Epoch 6/250
# 900/900 - 56s - 62ms/step - accuracy: 0.1228 - loss: 2.6447 - val_accuracy: 0.1369 - val_loss: 2.6311
# Epoch 7/250
# 900/900 - 56s - 62ms/step - accuracy: 0.1223 - loss: 2.6865 - val_accuracy: 0.1336 - val_loss: 2.5985
# Epoch 8/250
# 900/900 - 56s - 62ms/step - accuracy: 0.1276 - loss: 2.6596 - val_accuracy: 0.1326 - val_loss: 2.6056
# Epoch 9/250
# 900/900 - 56s - 62ms/step - accuracy: 0.
250
# 900/900 - 56s - 62ms/step - accuracy: 0.5156 - loss: 1.2174 - val_accuracy: 0.5322 - val_loss: 1.1786
# Epoch 137/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5169 - loss: 1.2153 - val_accuracy: 0.5157 - val_loss: 1.2138
# Epoch 138/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5195 - loss: 1.2096 - val_accuracy: 0.4994 - val_loss: 1.2501
# Epoch 139/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5225 - loss: 1.2094 - val_accuracy: 0.5275 - val_loss: 1.1802
# Epoch 140/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5252 - loss: 1.1934 - val_accuracy: 0.5296 - val_loss: 1.1794
# Epoch 141/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5253 - loss: 1.1932 - val_accuracy: 0.5243 - val_loss: 1.1749
# Epoch 142/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5283 - loss: 1.1910 - val_accuracy: 0.5350 - val_loss: 1.1678
# Epoch 143/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5337 - loss: 1.1727 - val_accuracy: 0.5262 - val_loss: 1.1902
# Epoch 144/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5289 - loss: 1.1801 - val_accuracy: 0.5287 - val_loss: 1.2087
# Epoch 145/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5328 - loss: 1.1712 - val_accuracy: 0.5259 - val_loss: 1.2147
# Epoch 146/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5333 - loss: 1.1784 - val_accuracy: 0.5406 - val_loss: 1.1487
# Epoch 147/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5359 - loss: 1.1681 - val_accuracy: 0.5392 - val_loss: 1.1479
# Epoch 148/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5378 - loss: 1.1617 - val_accuracy: 0.5435 - val_loss: 1.1345
# Epoch 149/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5420 - loss: 1.1477 - val_accuracy: 0.5463 - val_loss: 1.1232
# Epoch 150/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5441 - loss: 1.1450 - val_accuracy: 0.5462 - val_loss: 1.1267
# Epoch 151/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5476 - loss: 1.1322 - val_accuracy: 0.5530 - val_loss: 1.1175
# Epoch 152/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5455 - loss: 1.1341 - val_accuracy: 0.5487 - val_loss: 1.1308
# Epoch 153/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5511 - loss: 1.1246 - val_accuracy: 0.5554 - val_loss: 1.0985
# Epoch 154/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5537 - loss: 1.1107 - val_accuracy: 0.5508 - val_loss: 1.1180
# Epoch 155/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5549 - loss: 1.1022 - val_accuracy: 0.5447 - val_loss: 1.1565
# Epoch 156/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5561 - loss: 1.1000 - val_accuracy: 0.5543 - val_loss: 1.1011
# Epoch 157/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5595 - loss: 1.0901 - val_accuracy: 0.5635 - val_loss: 1.0762
# Epoch 158/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5612 - loss: 1.0848 - val_accuracy: 0.5642 - val_loss: 1.0763
# Epoch 159/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5655 - loss: 1.0787 - val_accuracy: 0.5583 - val_loss: 1.0869
# Epoch 160/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5634 - loss: 1.0855 - val_accuracy: 0.5640 - val_loss: 1.0851
# Epoch 161/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5649 - loss: 1.0727 - val_accuracy: 0.5533 - val_loss: 1.1220
# Epoch 162/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5647 - loss: 1.0771 - val_accuracy: 0.5638 - val_loss: 1.0750
# Epoch 163/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5707 - loss: 1.0568 - val_accuracy: 0.5656 - val_loss: 1.0737
# Epoch 164/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5720 - loss: 1.0550 - val_accuracy: 0.5643 - val_loss: 1.0724
# Epoch 165/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5723 - loss: 1.0560 - val_accuracy: 0.5572 - val_loss: 1.0818
# Epoch 166/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5728 - loss: 1.0543 - val_accuracy: 0.5763 - val_loss: 1.0422
# Epoch 167/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5795 - loss: 1.0348 - val_accuracy: 0.5752 - val_loss: 1.0449
# Epoch 168/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5794 - loss: 1.0282 - val_accuracy: 0.5802 - val_loss: 1.0278
# Epoch 169/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5804 - loss: 1.0263 - val_accuracy: 0.5615 - val_loss: 1.0670
# Epoch 170/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5849 - loss: 1.0218 - val_accuracy: 0.5832 - val_loss: 1.0169
# Epoch 171/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5836 - loss: 1.0196 - val_accuracy: 0.5818 - val_loss: 1.0211
# Epoch 172/250
# 900/900 - 56s - 63ms/step - accuracy: 0.5901 - loss: 1.0045 - val_accuracy: 0.5781 - val_loss: 1.0711
# Epoch 173/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5935 - loss: 0.9954 - val_accuracy: 0.5897 - val_loss: 0.9916
# Epoch 174/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5957 - loss: 0.9924 - val_accuracy: 0.5949 - val_loss: 0.9833
# Epoch 175/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5951 - loss: 0.9865 - val_accuracy: 0.5885 - val_loss: 1.0486
# Epoch 176/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5930 - loss: 1.0037 - val_accuracy: 0.5817 - val_loss: 1.0410
# Epoch 177/250
# 900/900 - 56s - 62ms/step - accuracy: 0.5995 - loss: 0.9781 - val_accuracy: 0.5961 - val_loss: 0.9842
# Epoch 178/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6058 - loss: 0.9621 - val_accuracy: 0.5964 - val_loss: 0.9948
# Epoch 179/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6049 - loss: 0.9613 - val_accuracy: 0.6046 - val_loss: 0.9677
# Epoch 180/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6102 - loss: 0.9527 - val_accuracy: 0.6124 - val_loss: 0.9516
# Epoch 181/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6097 - loss: 0.9531 - val_accuracy: 0.6077 - val_loss: 0.9510
# Epoch 182/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6147 - loss: 0.9436 - val_accuracy: 0.6090 - val_loss: 0.9649
# Epoch 183/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6137 - loss: 0.9423 - val_accuracy: 0.6110 - val_loss: 0.9509
# Epoch 184/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6159 - loss: 0.9360 - val_accuracy: 0.6071 - val_loss: 0.9465
# Epoch 185/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6159 - loss: 0.9308 - val_accuracy: 0.6065 - val_loss: 1.0018
# Epoch 186/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6216 - loss: 0.9268 - val_accuracy: 0.6232 - val_loss: 0.9249
# Epoch 187/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6231 - loss: 0.9213 - val_accuracy: 0.6207 - val_loss: 0.9334
# Epoch 188/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6267 - loss: 0.9071 - val_accuracy: 0.6251 - val_loss: 0.9114
# Epoch 189/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6201 - loss: 0.9245 - val_accuracy: 0.5847 - val_loss: 1.0217
# Epoch 190/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6276 - loss: 0.9098 - val_accuracy: 0.6230 - val_loss: 0.9245
# Epoch 191/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6319 - loss: 0.8998 - val_accuracy: 0.6261 - val_loss: 0.9174
# Epoch 192/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6364 - loss: 0.8854 - val_accuracy: 0.6362 - val_loss: 0.8990
# Epoch 193/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6386 - loss: 0.8810 - val_accuracy: 0.6325 - val_loss: 0.8945
# Epoch 194/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6394 - loss: 0.8883 - val_accuracy: 0.6372 - val_loss: 0.8899
# Epoch 195/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6469 - loss: 0.8637 - val_accuracy: 0.6447 - val_loss: 0.8704
# Epoch 196/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6427 - loss: 0.8815 - val_accuracy: 0.6446 - val_loss: 0.8651
# Epoch 197/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6514 - loss: 0.8543 - val_accuracy: 0.6386 - val_loss: 0.9024
# Epoch 198/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6574 - loss: 0.8403 - val_accuracy: 0.6432 - val_loss: 0.8747
# Epoch 199/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6596 - loss: 0.8308 - val_accuracy: 0.6500 - val_loss: 0.8470
# Epoch 200/250
# 900/900 - 56s - 62ms/step - accuracy: 0.6596 - loss: 0.8249 - val_accuracy: 0.6607 - val_loss: 0.8330
# Epoch 201/250
# 900/900 - 56s - 62ms/step - accuracy: 0.
250
# 900/900 - 56s - 62ms/step - accuracy: 0.7003 - loss: 0.7112 - val_accuracy: 0.6740 - val_loss: 0.8048
# Epoch 234/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7015 - loss: 0.7100 - val_accuracy: 0.6950 - val_loss: 0.7438
# Epoch 235/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7044 - loss: 0.7020 - val_accuracy: 0.6866 - val_loss: 0.7553
# Epoch 236/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7074 - loss: 0.6917 - val_accuracy: 0.6815 - val_loss: 0.7728
# Epoch 237/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7063 - loss: 0.7002 - val_accuracy: 0.6919 - val_loss: 0.7491
# Epoch 238/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7056 - loss: 0.6991 - val_accuracy: 0.6925 - val_loss: 0.7474
# Epoch 239/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7093 - loss: 0.6896 - val_accuracy: 0.6897 - val_loss: 0.7634
# Epoch 240/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7104 - loss: 0.6910 - val_accuracy: 0.6918 - val_loss: 0.7574
# Epoch 241/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7091 - loss: 0.6895 - val_accuracy: 0.6992 - val_loss: 0.7441
# Epoch 242/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7107 - loss: 0.6824 - val_accuracy: 0.6966 - val_loss: 0.7314
# Epoch 243/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7110 - loss: 0.6828 - val_accuracy: 0.6759 - val_loss: 0.8101
# Epoch 244/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7101 - loss: 0.6823 - val_accuracy: 0.6964 - val_loss: 0.7478
# Epoch 245/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7105 - loss: 0.6783 - val_accuracy: 0.6931 - val_loss: 0.7641
# Epoch 246/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7140 - loss: 0.6757 - val_accuracy: 0.6927 - val_loss: 0.7581
# Epoch 247/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7149 - loss: 0.6741 - val_accuracy: 0.6989 - val_loss: 0.7459
# Epoch 248/250
# 900/900 - 56s - 63ms/step - accuracy: 0.7133 - loss: 0.6765 - val_accuracy: 0.6949 - val_loss: 0.7515
# Epoch 249/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7148 - loss: 0.6751 - val_accuracy: 0.7017 - val_loss: 0.7360
# Epoch 250/250
# 900/900 - 56s - 62ms/step - accuracy: 0.7180 - loss: 0.6697 - val_accuracy: 0.6937 - val_loss: 0.7425
# Classification Report (All SNRs):
#               precision    recall  f1-score   support
#
#      128APSK       0.36      0.16      0.23      3000
#       128QAM       0.42      0.49      0.45      3000
#       16APSK       0.91      0.90      0.90      3000
#        16PSK       0.86      0.76      0.81      3000
#        16QAM       0.75      0.92      0.83      3000
#       256QAM       0.92      0.74      0.82      3000
#       32APSK       0.87      0.80      0.83      3000
#        32PSK       0.98      0.97      0.98      3000
#        32QAM       0.91      0.90      0.90      3000
#         4ASK       0.63      0.56      0.60      3000
#       64APSK       0.45      0.69      0.54      3000
#        64QAM       0.60      0.84      0.70      3000
#         8ASK       0.46      0.83      0.60      3000
#         8PSK       0.63      0.90      0.74      3000
#    AM-DSB-SC       0.39      0.15      0.22      3000
#    AM-DSB-WC       1.00      1.00      1.00      3000
#    AM-SSB-SC       0.66      0.60      0.63      3000
#    AM-SSB-WC       0.71      0.45      0.55      3000
#         BPSK       0.78      0.85      0.81      3000
#           FM       0.94      0.98      0.96      3000
#         GMSK       0.88      0.87      0.87      3000
#          OOK       0.84      0.96      0.90      3000
#        OQPSK       0.29      0.04      0.06      3000
#         QPSK       0.78      0.94      0.85      3000
#
#     accuracy                           0.72     72000
#    macro avg       0.71      0.72      0.70     72000
# weighted avg       0.71      0.72      0.70     72000
# ✅ Model saved to rml2018_lstm_model.keras
