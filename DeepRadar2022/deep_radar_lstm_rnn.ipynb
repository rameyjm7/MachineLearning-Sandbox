# %%
# https://www.kaggle.com/jacobramey
# https://github.com/rameyjm7

import kagglehub
import numpy as np
import h5py, scipy.io as sio, os, sklearn
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout, BatchNormalization
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import mixed_precision
import tensorflow as tf

# ------------------------------
# Load DeepRadar2022 dataset
# ------------------------------
path = kagglehub.dataset_download("khilian/deepradar")
print("Dataset path:", path)

def load_h5(filepath, key):
    with h5py.File(filepath, "r") as f:
        return np.array(f[key], dtype="float32").T

def load_mat(filepath, key):
    d = sio.loadmat(filepath)
    return d[key]

X_train = load_h5(os.path.join(path, "X_train.mat"), "X_train")
X_val   = load_h5(os.path.join(path, "X_val.mat"), "X_val")
X_test  = load_h5(os.path.join(path, "X_test.mat"), "X_test")

Y_train = load_mat(os.path.join(path, "Y_train.mat"), "Y_train")
Y_val   = load_mat(os.path.join(path, "Y_val.mat"), "Y_val")
Y_test  = load_mat(os.path.join(path, "Y_test.mat"), "Y_test")

lbl_train = load_mat(os.path.join(path, "lbl_train.mat"), "lbl_train")
lbl_val   = load_mat(os.path.join(path, "lbl_val.mat"), "lbl_val")
lbl_test  = load_mat(os.path.join(path, "lbl_test.mat"), "lbl_test")

# Extract modulation class and SNR
cls_train, snr_train = lbl_train[:,0].astype(int)-1, lbl_train[:,1]
cls_val,   snr_val   = lbl_val[:,0].astype(int)-1,   lbl_val[:,1]
cls_test,  snr_test  = lbl_test[:,0].astype(int)-1,  lbl_test[:,1]

# ------------------------------
# Filter training/validation by SNR ≥ -6 dB
# ------------------------------
train_mask = snr_train >= -6
val_mask   = snr_val >= -6
X_train, Y_train, snr_train = X_train[train_mask], Y_train[train_mask], snr_train[train_mask]
X_val,   Y_val,   snr_val   = X_val[val_mask],   Y_val[val_mask],   snr_val[val_mask]

print(f"Training samples kept: {X_train.shape[0]} | Validation: {X_val.shape[0]} | Test: {X_test.shape[0]}")

# ------------------------------
# Shuffle
# ------------------------------
np.random.seed(1961)
X_train, Y_train, snr_train = sklearn.utils.shuffle(X_train, Y_train, snr_train, random_state=1961)
X_val,   Y_val,   snr_val   = sklearn.utils.shuffle(X_val, Y_val, snr_val, random_state=1961)
X_test,  Y_test,  snr_test  = sklearn.utils.shuffle(X_test, Y_test, snr_test, random_state=1961)

# ------------------------------
# Normalize IQ per sample
# ------------------------------
def normalize_iq(X):
    Xn = np.empty_like(X)
    for i in range(X.shape[0]):
        scale = np.max(np.abs(X[i])) + 1e-12
        Xn[i] = X[i] / scale
    return Xn

X_train = normalize_iq(X_train)
X_val   = normalize_iq(X_val)
X_test  = normalize_iq(X_test)

# ------------------------------
# Append SNR as a third channel
# ------------------------------
def append_snr_feature(X, snr):
    X_out = []
    for i in range(X.shape[0]):
        snr_col = np.full((X.shape[1], 1), snr[i] / 20.0)  # normalized to roughly [-0.6, 1]
        X_out.append(np.concatenate([X[i], snr_col], axis=1))
    return np.array(X_out, dtype=np.float32)

X_train = append_snr_feature(X_train, snr_train)
X_val   = append_snr_feature(X_val, snr_val)
X_test  = append_snr_feature(X_test, snr_test)

input_shape = (1024, 3)
num_classes = 23

# ------------------------------
# Enable mixed precision
# ------------------------------
mixed_precision.set_global_policy("mixed_float16")

# ------------------------------
# Build CNN + Bidirectional LSTM model
# ------------------------------
def build_cnn_bilstm(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv1D(64, 5, activation="relu", padding="same"),
        BatchNormalization(),
        MaxPooling1D(2),
        Conv1D(128, 3, activation="relu", padding="same"),
        BatchNormalization(),
        MaxPooling1D(2),
        Bidirectional(LSTM(128, return_sequences=True)),
        Dropout(0.3),
        Bidirectional(LSTM(64)),
        Dense(128, activation="relu"),
        Dropout(0.3),
        Dense(num_classes, activation="softmax", dtype="float32")
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

model = build_cnn_bilstm(input_shape, num_classes)
model.summary()

# ------------------------------
# Training setup
# ------------------------------
callbacks = [
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-5, verbose=1),
    ModelCheckpoint("deepradar2022_cnn_bilstm_highsnr.keras", save_best_only=True)
]

history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=35,
    batch_size=128,
    callbacks=callbacks,
    verbose=1
)

# ------------------------------
# Evaluate on full test set (all SNRs)
# ------------------------------
loss, acc = model.evaluate(X_test, Y_test, verbose=0)
print(f"\nTest Accuracy (all SNRs): {acc*100:.2f}%")

Y_pred = model.predict(X_test, verbose=0)
y_true = np.argmax(Y_test, axis=1)
y_pred = np.argmax(Y_pred, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, cmap="Blues")
plt.xlabel("Predicted"); plt.ylabel("True")
plt.title("Confusion Matrix (CNN + BiLSTM, Trained ≥ –6 dB, Evaluated All)")
plt.show()

print("Classification Report:")
print(classification_report(y_true, y_pred))

# ------------------------------
# Accuracy vs SNR
# ------------------------------
unique_snrs = sorted(np.unique(snr_test))
acc_snr = []
for snr in unique_snrs:
    idx = np.where(snr_test == snr)[0]
    acc_snr.append(accuracy_score(y_true[idx], y_pred[idx]) * 100)

plt.figure(figsize=(8,5))
plt.plot(unique_snrs, acc_snr, 'b-o')
plt.xlabel("SNR (dB)")
plt.ylabel("Accuracy (%)")
plt.title("Recognition Accuracy vs SNR (CNN + BiLSTM, Trained ≥ –6 dB)")
plt.grid(True)
plt.show()
# Out:
# Dataset path: /home/rameyjm7/.cache/kagglehub/datasets/khilian/deepradar/versions/1
# Training samples kept: 386400 | Validation: 128800 | Test: 156400
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 1024, 64)       │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 512, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 512, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 256, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 256, 256)       │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 128)            │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 23)             │         2,967 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 473,495 (1.81 MB)
#  Trainable params: 473,111 (1.80 MB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 139s 43ms/step - accuracy: 0.5056 - loss: 1.3069 - val_accuracy: 0.6998 - val_loss: 0.7291 - learning_rate: 5.0000e-04
# Epoch 2/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.7333 - loss: 0.6548 - val_accuracy: 0.7891 - val_loss: 0.4909 - learning_rate: 5.0000e-04
# Epoch 3/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.8023 - loss: 0.4772 - val_accuracy: 0.8238 - val_loss: 0.4210 - learning_rate: 5.0000e-04
# Epoch 4/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.8372 - loss: 0.3883 - val_accuracy: 0.8458 - val_loss: 0.3611 - learning_rate: 5.0000e-04
# Epoch 5/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.8595 - loss: 0.3323 - val_accuracy: 0.8655 - val_loss: 0.3042 - learning_rate: 5.0000e-04
# Epoch 6/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.8751 - loss: 0.2949 - val_accuracy: 0.8778 - val_loss: 0.2804 - learning_rate: 5.0000e-04
# Epoch 7/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.8876 - loss: 0.2642 - val_accuracy: 0.8825 - val_loss: 0.2715 - learning_rate: 5.0000e-04
# Epoch 8/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.8977 - loss: 0.2415 - val_accuracy: 0.8953 - val_loss: 0.2437 - learning_rate: 5.0000e-04
# Epoch 9/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9043 - loss: 0.2239 - val_accuracy: 0.8981 - val_loss: 0.2361 - learning_rate: 5.0000e-04
# Epoch 10/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9110 - loss: 0.2091 - val_accuracy: 0.8968 - val_loss: 0.2446 - learning_rate: 5.0000e-04
# Epoch 11/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9154 - loss: 0.1994 - val_accuracy: 0.9065 - val_loss: 0.2305 - learning_rate: 5.0000e-04
# Epoch 12/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9202 - loss: 0.1865 - val_accuracy: 0.9092 - val_loss: 0.2177 - learning_rate: 5.0000e-04
# Epoch 13/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9249 - loss: 0.1769 - val_accuracy: 0.9108 - val_loss: 0.2087 - learning_rate: 5.0000e-04
# Epoch 14/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9285 - loss: 0.1671 - val_accuracy: 0.9155 - val_loss: 0.2102 - learning_rate: 5.0000e-04
# Epoch 15/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9308 - loss: 0.1618 - val_accuracy: 0.9130 - val_loss: 0.2083 - learning_rate: 5.0000e-04
# Epoch 16/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9343 - loss: 0.1541 - val_accuracy: 0.9216 - val_loss: 0.1915 - learning_rate: 5.0000e-04
# Epoch 17/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9365 - loss: 0.1484 - val_accuracy: 0.9235 - val_loss: 0.1828 - learning_rate: 5.0000e-04
# Epoch 18/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9402 - loss: 0.1402 - val_accuracy: 0.9230 - val_loss: 0.1882 - learning_rate: 5.0000e-04
# Epoch 19/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9413 - loss: 0.1363 - val_accuracy: 0.9189 - val_loss: 0.1930 - learning_rate: 5.0000e-04
# Epoch 20/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9437 - loss: 0.1313 - val_accuracy: 0.9258 - val_loss: 0.1823 - learning_rate: 5.0000e-04
# Epoch 21/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9463 - loss: 0.1255 - val_accuracy: 0.9251 - val_loss: 0.1881 - learning_rate: 5.0000e-04
# Epoch 22/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9482 - loss: 0.1222 - val_accuracy: 0.9240 - val_loss: 0.1883 - learning_rate: 5.0000e-04
# Epoch 23/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9493 - loss: 0.1170
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9491 - loss: 0.1182 - val_accuracy: 0.9275 - val_loss: 0.1833 - learning_rate: 5.0000e-04
# Epoch 24/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9588 - loss: 0.0938 - val_accuracy: 0.9350 - val_loss: 0.1664 - learning_rate: 2.5000e-04
# Epoch 25/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9612 - loss: 0.0873 - val_accuracy: 0.9348 - val_loss: 0.1697 - learning_rate: 2.5000e-04
# Epoch 26/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9630 - loss: 0.0829 - val_accuracy: 0.9351 - val_loss: 0.1681 - learning_rate: 2.5000e-04
# Epoch 27/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9650 - loss: 0.0785
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9647 - loss: 0.0794 - val_accuracy: 0.9333 - val_loss: 0.1809 - learning_rate: 2.5000e-04
# Epoch 28/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9695 - loss: 0.0677 - val_accuracy: 0.9385 - val_loss: 0.1725 - learning_rate: 1.2500e-04
# Epoch 29/35
# 3019/3019 ━━━━━━━━━━━━━━━━━━━━ 126s 42ms/step - accuracy: 0.9711 - loss: 0.0639 - val_accuracy: 0.9377 - val_loss: 0.1773 - learning_rate: 1.2500e-04
#
# Test Accuracy (all SNRs): 84.33%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      6800
#            1       0.82      0.84      0.83      6800
#            2       0.77      0.83      0.80      6800
#            3       0.86      0.84      0.85      6800
#            4       0.93      0.85      0.89      6800
#            5       0.79      0.83      0.81      6800
#            6       0.68      0.69      0.68      6800
#            7       0.74      0.59      0.66      6800
#            8       0.88      0.91      0.89      6800
#            9       0.94      0.90      0.92      6800
#           10       0.80      0.85      0.83      6800
#           11       0.83      0.79      0.81      6800
#           12       0.84      0.81      0.83      6800
#           13       0.87      0.82      0.84      6800
#           14       0.82      0.81      0.81      6800
#           15       0.76      0.90      0.82      6800
#           16       0.82      0.86      0.84      6800
#           17       0.88      0.87      0.87      6800
#           18       0.90      0.91      0.90      6800
#           19       0.90      0.85      0.88      6800
#           20       0.88      0.87      0.87      6800
#           21       0.92      0.92      0.92      6800
#           22       0.84      0.93      0.88      6800
#
#     accuracy                           0.84    156400
#    macro avg       0.84      0.84      0.84    156400
# weighted avg       0.84      0.84      0.84    156400

# %%
# ------------------------------
# Save final model in .keras format and plot labeled confusion matrices
# ------------------------------

save_path = "deepradar2022_cnn_bilstm_final.keras"

# Save model architecture, weights, and optimizer state in one file
model.save(save_path, include_optimizer=True)
print(f"Model saved successfully at: {os.path.abspath(save_path)}")

# ------------------------------
# Reload and verify
# ------------------------------
from tensorflow.keras.models import load_model
reloaded_model = load_model(save_path)
test_loss, test_acc = reloaded_model.evaluate(X_test, Y_test, verbose=0)
print(f"Reloaded model test accuracy: {test_acc*100:.2f}%")

# ------------------------------
# Confusion Matrices: Full vs High-SNR (≥ -6 dB)
# ------------------------------

# DeepRadar2022 modulation label map
mod_labels = [
    "LFM",
    "2FSK",
    "4FSK",
    "8FSK",
    "Costas",
    "2PSK",
    "4PSK",
    "8PSK",
    "Barker",
    "Huffman",
    "Frank",
    "P1",
    "P2",
    "P3",
    "P4",
    "Px",
    "Zadoff-Chu",
    "T1",
    "T2",
    "T3",
    "T4",
    "NM",
    "Noise"
]

# Predict
Y_pred = reloaded_model.predict(X_test, verbose=0)
y_true = np.argmax(Y_test, axis=1)
y_pred = np.argmax(Y_pred, axis=1)

# --- Confusion Matrix: All SNRs ---
cm_all = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(13, 11))
sns.heatmap(
    cm_all, annot=False, fmt="d", cmap="Blues",
    xticklabels=mod_labels, yticklabels=mod_labels
)
plt.xlabel("Predicted Modulation")
plt.ylabel("True Modulation")
plt.title("Confusion Matrix (All SNRs)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# --- Confusion Matrix: High-SNR (≥ -6 dB) ---
high_snr_mask = snr_test >= -6
y_true_high = y_true[high_snr_mask]
y_pred_high = y_pred[high_snr_mask]

cm_high = confusion_matrix(y_true_high, y_pred_high)
plt.figure(figsize=(13, 11))
sns.heatmap(
    cm_high, annot=False, fmt="d", cmap="Greens",
    xticklabels=mod_labels, yticklabels=mod_labels
)
plt.xlabel("Predicted Modulation")
plt.ylabel("True Modulation")
plt.title("Confusion Matrix (SNR ≥ -6 dB)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# --- Classification Reports ---
print("\nClassification Report (All SNRs):")
print(classification_report(y_true, y_pred, target_names=mod_labels, digits=3))

print("\nClassification Report (SNR ≥ -6 dB):")
print(classification_report(y_true_high, y_pred_high, target_names=mod_labels, digits=3))
# Out:
# Model saved successfully at: /home/rameyjm7/workspace/MachineLearning-Sandbox/DeepRadar2022/deepradar2022_cnn_bilstm_final.keras
# Reloaded model test accuracy: 84.33%
# Classification Report (All SNRs):
#               precision    recall  f1-score   support
#
#          LFM      0.973     0.938     0.955      6800
#         2FSK      0.820     0.836     0.828      6800
#         4FSK      0.769     0.826     0.797      6800
#         8FSK      0.864     0.837     0.850      6800
#       Costas      0.927     0.854     0.889      6800
#         2PSK      0.787     0.829     0.807      6800
#         4PSK      0.676     0.687     0.681      6800
#         8PSK      0.738     0.592     0.657      6800
#       Barker      0.877     0.906     0.892      6800
#      Huffman      0.936     0.898     0.916      6800
#        Frank      0.804     0.851     0.827      6800
#           P1      0.829     0.790     0.809      6800
#           P2      0.845     0.812     0.828      6800
#           P3      0.865     0.823     0.843      6800
#           P4      0.821     0.807     0.814      6800
#           Px      0.758     0.904     0.825      6800
#   Zadoff-Chu      0.818     0.862     0.839      6800
#           T1      0.878     0.866     0.872      6800
#           T2      0.895     0.908     0.901      6800
#           T3      0.903     0.851     0.876      6800
#           T4      0.881     0.869     0.875      6800
#           NM      0.921     0.924     0.923      6800
#        Noise      0.840     0.927     0.881      6800
#
#     accuracy                          0.843    156400
#    macro avg      0.845     0.843     0.843    156400
# weighted avg      0.845     0.843     0.843    156400
#
#
# Classification Report (SNR ≥ -6 dB):
#               precision    recall  f1-score   support
#
#          LFM      1.000     0.999     1.000      5600
#         2FSK      0.958     0.959     0.958      5600
#         4FSK      0.950     0.944     0.947      5600
#         8FSK      0.963     0.958     0.960      5600
#       Costas      0.974     0.959     0.966      5600
#         2PSK      0.900     0.951     0.925      5600
#         4PSK      0.735     0.804     0.768      5600
#         8PSK      0.828     0.693     0.755      5600
#       Barker      0.969     0.976     0.973      5600
#      Huffman      0.994     0.988     0.991      5600
#        Frank      0.929     0.963     0.945      5600
#           P1      0.890     0.915     0.902      5600
#           P2      0.942     0.924     0.933      5600
#           P3      0.971     0.932     0.951      5600
#           P4      0.933     0.920     0.927      5600
#           Px      0.970     0.987     0.978      5600
#   Zadoff-Chu      0.970     0.973     0.972      5600
#           T1      0.968     0.966     0.967      5600
#           T2      0.985     0.988     0.986      5600
#           T3      0.950     0.963     0.956      5600
#           T4      0.971     0.959     0.965      5600
#           NM      0.984     0.992     0.988      5600
#        Noise      0.978     0.993     0.985      5600
#
#     accuracy                          0.944    128800
#    macro avg      0.944     0.944     0.943    128800
# weighted avg      0.944     0.944     0.943    128800
