# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pickle

# ---------------------------------------------------------------------
# 🔹 SET YOUR LOCAL KAGGLE DATASET PATH HERE
# ---------------------------------------------------------------------
KAGGLE_CIFAR100_PATH = "/home/rameyjm7/.cache/kagglehub/datasets/alincijov/cifar-100/versions/1"

# ---------------------------------------------------------------------
# 🔹 Load CIFAR-100 from Kaggle (Python pickled format)
# ---------------------------------------------------------------------
def load_data():
    def load_batch(filename):
        with open(os.path.join(KAGGLE_CIFAR100_PATH, filename), "rb") as f:
            batch = pickle.load(f, encoding="latin1")
        data = batch["data"]
        labels = batch["fine_labels"]
        data = data.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)  # NCHW → NHWC
        return data, np.array(labels)

    x_train, y_train = load_batch("train")
    x_test, y_test = load_batch("test")

    # Normalize and one-hot encode
    x_train, x_test = x_train / 255.0, x_test / 255.0
    num_classes = 100
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return x_train, y_train, x_test, y_test, num_classes

# ---------------------------------------------------------------------
# 🔹 Build model (ResNet50, lightweight for Jetson)
# ---------------------------------------------------------------------
def build_model(num_classes):
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(256, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# ---------------------------------------------------------------------
# 🔹 Train and evaluate
# ---------------------------------------------------------------------
def train_and_evaluate():
    x_train, y_train, x_test, y_test, num_classes = load_data()
    model = build_model(num_classes)

    print("\n--- Training on CIFAR-100 (Kaggle version) ---")
    history = model.fit(
        x_train, y_train,
        validation_data=(x_test, y_test),
        epochs=20,
        batch_size=64,
        verbose=1
    )

    print("\n--- Evaluating on test set ---")
    y_pred = np.argmax(model.predict(x_test), axis=1)
    y_true = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_true, y_pred)

    return model, x_test, y_pred, y_true, cm

# ---------------------------------------------------------------------
# 🔹 Run
# ---------------------------------------------------------------------
trained_model, test_images, test_preds, test_labels, final_cm = train_and_evaluate()

# ---------------------------------------------------------------------
# 🔹 Plot confusion matrix
# ---------------------------------------------------------------------
def plot_confusion_matrix(cm, labels):
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm_norm, annot=False, fmt=".2f", cmap="Blues",
                xticklabels=labels, yticklabels=labels)
    plt.title("Normalized Confusion Matrix - CIFAR-100 (Kaggle)")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

cifar100_labels = list(range(100))
plot_confusion_matrix(final_cm, cifar100_labels)
# Out:
# 2025-10-26 20:05:07.572960: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761523517.193008 4008263 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79196 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:87:00.0, compute capability: 8.0
# --- Training on CIFAR-100 (Kaggle version) ---
# Epoch 1/20
# 2025-10-26 20:05:41.455649: I external/local_xla/xla/service/service.cc:163] XLA service 0x1552380026c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-26 20:05:41.455683: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# 2025-10-26 20:05:42.216203: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-26 20:05:45.813720: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91400
# 2025-10-26 20:05:47.367553: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:05:47.367598: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:05:47.367717: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:05:47.367733: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:05:47.871040: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15211', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-26 20:05:48.363122: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15450', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 20:05:48.552492: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15466', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-10-26 20:05:48.590498: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15464', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-10-26 20:05:48.687950: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15450', 84 bytes spill stores, 84 bytes spill loads
#
# 2025-10-26 20:05:48.694375: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15466', 116 bytes spill stores, 116 bytes spill loads
#
# 2025-10-26 20:05:48.751542: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15466', 320 bytes spill stores, 320 bytes spill loads
#
# 2025-10-26 20:05:48.841441: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15464', 260 bytes spill stores, 260 bytes spill loads
#
# 2025-10-26 20:05:49.052136: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15464', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-10-26 20:05:49.251499: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15466', 472 bytes spill stores, 472 bytes spill loads
#   9/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.0132 - loss: 5.6853
# I0000 00:00:1761523565.711039 4010580 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 46ms/step - accuracy: 0.1331 - loss: 3.9723 - val_accuracy: 0.0987 - val_loss: 4.1788
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.3445 - loss: 2.6483 - val_accuracy: 0.4299 - val_loss: 2.2373
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.4622 - loss: 2.0751 - val_accuracy: 0.4806 - val_loss: 2.0067
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5469 - loss: 1.6859 - val_accuracy: 0.5115 - val_loss: 1.8732
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.6166 - loss: 1.3915 - val_accuracy: 0.5157 - val_loss: 1.9386
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.6726 - loss: 1.1571 - val_accuracy: 0.5308 - val_loss: 1.8952
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7306 - loss: 0.9332 - val_accuracy: 0.5407 - val_loss: 1.9352
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7720 - loss: 0.7694 - val_accuracy: 0.5352 - val_loss: 2.0491
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8118 - loss: 0.6353 - val_accuracy: 0.5444 - val_loss: 2.0590
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8424 - loss: 0.5221 - val_accuracy: 0.5457 - val_loss: 2.1692
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8695 - loss: 0.4337 - val_accuracy: 0.5436 - val_loss: 2.2744
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8848 - loss: 0.3784 - val_accuracy: 0.5480 - val_loss: 2.3187
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9001 - loss: 0.3273 - val_accuracy: 0.5432 - val_loss: 2.4031
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9132 - loss: 0.2864 - val_accuracy: 0.5459 - val_loss: 2.4309
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9214 - loss: 0.2554 - val_accuracy: 0.5416 - val_loss: 2.5551
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9296 - loss: 0.2332 - val_accuracy: 0.5367 - val_loss: 2.5854
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9326 - loss: 0.2223 - val_accuracy: 0.5484 - val_loss: 2.6097
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9351 - loss: 0.2128 - val_accuracy: 0.5501 - val_loss: 2.6384
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9404 - loss: 0.1984 - val_accuracy: 0.5488 - val_loss: 2.5956
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9483 - loss: 0.1682 - val_accuracy: 0.5418 - val_loss: 2.7476
#
# --- Evaluating on test set ---
# 2025-10-26 20:10:24.415772: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:10:24.415812: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:10:24.803188: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 20:10:24.894921: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1699', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-26 20:10:25.006067: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 20:10:25.006095: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1699', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-10-26 20:10:25.051129: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1699', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-26 20:10:25.051166: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1699', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-10-26 20:10:25.378055: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1692', 20 bytes spill stores, 20 bytes spill loads
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step

# %%
import os
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# ---------------------------------------------------------------------
# 🔹 Path to Kaggle CIFAR-100 dataset
# ---------------------------------------------------------------------
KAGGLE_CIFAR100_PATH = "/home/rameyjm7/.cache/kagglehub/datasets/alincijov/cifar-100/versions/1"

# ---------------------------------------------------------------------
# 🔹 Replay Buffer for Balancing Data
# ---------------------------------------------------------------------
class ReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = []
        self.capacity = capacity

    def add_samples(self, x, y):
        if len(self.buffer) >= self.capacity:
            self.buffer = self.buffer[len(y):]
        self.buffer.extend(zip(x, y))

    def get_samples(self, batch_size=1000):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        samples = [self.buffer[i] for i in indices]
        x_replay, y_replay = zip(*samples)
        return np.array(x_replay), np.array(y_replay)

# ---------------------------------------------------------------------
# 🔹 Load CIFAR-100 Data (from Kaggle pickled files)
# ---------------------------------------------------------------------
def load_data():
    def load_batch(filename):
        with open(os.path.join(KAGGLE_CIFAR100_PATH, filename), "rb") as f:
            batch = pickle.load(f, encoding="latin1")
        data = batch["data"]
        labels = batch["fine_labels"]
        data = data.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
        return data, np.array(labels)

    x_train, y_train = load_batch("train")
    x_test, y_test = load_batch("test")

    # Normalize
    x_train, x_test = x_train / 255.0, x_test / 255.0

    # One-hot encode
    num_classes = 100
    y_train, y_test = to_categorical(y_train, num_classes), to_categorical(y_test, num_classes)
    return x_train, y_train, x_test, y_test, num_classes

# ---------------------------------------------------------------------
# 🔹 Fine-tuning with Replay Buffer & LR decay
# ---------------------------------------------------------------------
def fine_tune_model(trained_model, x_train, y_train, x_test, y_test):
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=1e-4,
        decay_steps=20000,
        decay_rate=0.9
    )
    optimizer = Adam(learning_rate=lr_schedule)
    trained_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

    print("\n--- Fine-tuning model on CIFAR-100 ---")
    history = trained_model.fit(
        x_train, y_train,
        validation_data=(x_test, y_test),
        epochs=50,
        batch_size=64,
        verbose=1
    )
    return history

# ---------------------------------------------------------------------
# 🔹 Build, train, and return model
# ---------------------------------------------------------------------
def train_final_model():
    x_train, y_train, x_test, y_test, num_classes = load_data()

    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(256, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

    print("\n--- Initial training on CIFAR-100 ---")
    history = model.fit(
        x_train, y_train,
        validation_data=(x_test, y_test),
        epochs=50,
        batch_size=64,
        verbose=1
    )

    return model, x_test, y_test

# ---------------------------------------------------------------------
# 🔹 Train, fine-tune, evaluate
# ---------------------------------------------------------------------
trained_model, final_x_test, final_y_test = train_final_model()
fine_tune_model(trained_model, final_x_test, final_y_test, final_x_test, final_y_test)

# ---------------------------------------------------------------------
# 🔹 Confusion Matrix
# ---------------------------------------------------------------------
final_predictions = np.argmax(trained_model.predict(final_x_test), axis=1)
final_true_labels = np.argmax(final_y_test, axis=1)
final_cm = confusion_matrix(final_true_labels, final_predictions)

# ---------------------------------------------------------------------
# 🔹 Plot Normalized Confusion Matrix
# ---------------------------------------------------------------------
def plot_confusion_matrix(cm, labels):
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm_norm, annot=False, fmt=".2f", cmap="Blues",
                xticklabels=labels, yticklabels=labels)
    plt.title("Final Normalized Confusion Matrix (CIFAR-100, Kaggle)")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

plot_confusion_matrix(final_cm, list(range(100)))
# Out:
# --- Initial training on CIFAR-100 ---
# Epoch 1/50
# 2025-10-26 20:11:00.214787: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 20:11:00.846448: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17188', 260 bytes spill stores, 260 bytes spill loads
#
# 2025-10-26 20:11:00.894838: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17188', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-10-26 20:11:00.939011: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17188', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-10-26 20:11:01.049601: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17170', 11652 bytes spill stores, 11940 bytes spill loads
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - accuracy: 0.0558 - loss: 4.4155 - val_accuracy: 0.0766 - val_loss: 4.2143
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.2198 - loss: 3.2973 - val_accuracy: 0.3496 - val_loss: 2.6291
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.3617 - loss: 2.5406 - val_accuracy: 0.4365 - val_loss: 2.2110
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.4536 - loss: 2.1074 - val_accuracy: 0.4812 - val_loss: 2.0001
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5240 - loss: 1.7963 - val_accuracy: 0.5006 - val_loss: 1.9515
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5854 - loss: 1.5278 - val_accuracy: 0.5191 - val_loss: 1.9405
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.6392 - loss: 1.3140 - val_accuracy: 0.5433 - val_loss: 1.8719
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.6861 - loss: 1.1145 - val_accuracy: 0.5329 - val_loss: 1.9659
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7277 - loss: 0.9636 - val_accuracy: 0.5395 - val_loss: 2.0156
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7657 - loss: 0.8262 - val_accuracy: 0.5424 - val_loss: 2.0503
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8002 - loss: 0.7015 - val_accuracy: 0.5437 - val_loss: 2.0977
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8277 - loss: 0.5976 - val_accuracy: 0.5436 - val_loss: 2.1984
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8449 - loss: 0.5339 - val_accuracy: 0.5494 - val_loss: 2.2291
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8664 - loss: 0.4599 - val_accuracy: 0.5415 - val_loss: 2.3445
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.8819 - loss: 0.4091 - val_accuracy: 0.5512 - val_loss: 2.3494
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.8952 - loss: 0.3710 - val_accuracy: 0.5534 - val_loss: 2.3917
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9043 - loss: 0.3348 - val_accuracy: 0.5461 - val_loss: 2.4893
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9118 - loss: 0.3045 - val_accuracy: 0.5550 - val_loss: 2.4956
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9203 - loss: 0.2724 - val_accuracy: 0.5532 - val_loss: 2.5496
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9271 - loss: 0.2529 - val_accuracy: 0.5506 - val_loss: 2.5845
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9318 - loss: 0.2394 - val_accuracy: 0.5416 - val_loss: 2.6924
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9344 - loss: 0.2332 - val_accuracy: 0.5372 - val_loss: 2.6600
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9400 - loss: 0.2117 - val_accuracy: 0.5497 - val_loss: 2.7158
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9430 - loss: 0.2014 - val_accuracy: 0.5419 - val_loss: 2.7157
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9442 - loss: 0.1995 - val_accuracy: 0.5537 - val_loss: 2.6401
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9521 - loss: 0.1700 - val_accuracy: 0.5550 - val_loss: 2.7191
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9503 - loss: 0.1783 - val_accuracy: 0.5461 - val_loss: 2.7513
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9525 - loss: 0.1670 - val_accuracy: 0.5505 - val_loss: 2.7452
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9568 - loss: 0.1527 - val_accuracy: 0.5520 - val_loss: 2.8429
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9548 - loss: 0.1603 - val_accuracy: 0.5506 - val_loss: 2.7461
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9565 - loss: 0.1586 - val_accuracy: 0.5514 - val_loss: 2.7504
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9600 - loss: 0.1417 - val_accuracy: 0.5530 - val_loss: 2.7533
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9597 - loss: 0.1438 - val_accuracy: 0.5435 - val_loss: 2.8485
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9603 - loss: 0.1463 - val_accuracy: 0.5546 - val_loss: 2.7924
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9637 - loss: 0.1322 - val_accuracy: 0.5450 - val_loss: 2.8556
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9607 - loss: 0.1417 - val_accuracy: 0.5539 - val_loss: 2.7851
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9648 - loss: 0.1273 - val_accuracy: 0.5518 - val_loss: 2.8880
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9640 - loss: 0.1294 - val_accuracy: 0.5489 - val_loss: 2.9344
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9654 - loss: 0.1239 - val_accuracy: 0.5548 - val_loss: 2.8363
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9672 - loss: 0.1164 - val_accuracy: 0.5453 - val_loss: 2.8746
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9669 - loss: 0.1158 - val_accuracy: 0.5581 - val_loss: 2.8875
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9678 - loss: 0.1145 - val_accuracy: 0.5471 - val_loss: 2.9742
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9683 - loss: 0.1145 - val_accuracy: 0.5454 - val_loss: 3.0722
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9699 - loss: 0.1099 - val_accuracy: 0.5507 - val_loss: 2.9082
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9695 - loss: 0.1098 - val_accuracy: 0.5565 - val_loss: 2.8468
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9715 - loss: 0.1052 - val_accuracy: 0.5503 - val_loss: 2.8852
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9711 - loss: 0.1059 - val_accuracy: 0.5424 - val_loss: 2.9914
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9732 - loss: 0.0980 - val_accuracy: 0.5472 - val_loss: 2.9427
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9709 - loss: 0.1076 - val_accuracy: 0.5572 - val_loss: 2.8445
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9727 - loss: 0.0993 - val_accuracy: 0.5531 - val_loss: 2.9609
#
# --- Fine-tuning model on CIFAR-100 ---
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 63s 163ms/step - accuracy: 0.5348 - loss: 2.1822 - val_accuracy: 0.7096 - val_loss: 1.1641
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6830 - loss: 1.3279 - val_accuracy: 0.8238 - val_loss: 0.6765
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7813 - loss: 0.8824 - val_accuracy: 0.8883 - val_loss: 0.4134
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8519 - loss: 0.5768 - val_accuracy: 0.9329 - val_loss: 0.2564
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8976 - loss: 0.3979 - val_accuracy: 0.9580 - val_loss: 0.1584
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9306 - loss: 0.2662 - val_accuracy: 0.9759 - val_loss: 0.0918
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9512 - loss: 0.1857 - val_accuracy: 0.9806 - val_loss: 0.0721
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9608 - loss: 0.1497 - val_accuracy: 0.9905 - val_loss: 0.0375
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9629 - loss: 0.1382 - val_accuracy: 0.9887 - val_loss: 0.0426
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9649 - loss: 0.1243 - val_accuracy: 0.9899 - val_loss: 0.0396
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9676 - loss: 0.1172 - val_accuracy: 0.9910 - val_loss: 0.0527
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9719 - loss: 0.0999 - val_accuracy: 0.9920 - val_loss: 0.0485
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9707 - loss: 0.1036 - val_accuracy: 0.9961 - val_loss: 0.0162
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9736 - loss: 0.0940 - val_accuracy: 0.9900 - val_loss: 0.0962
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9755 - loss: 0.0871 - val_accuracy: 0.9972 - val_loss: 0.0106
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9788 - loss: 0.0795 - val_accuracy: 0.9943 - val_loss: 0.0240
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9788 - loss: 0.0767 - val_accuracy: 0.9971 - val_loss: 0.0124
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9790 - loss: 0.0783 - val_accuracy: 0.9943 - val_loss: 0.0267
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9835 - loss: 0.0605 - val_accuracy: 0.9949 - val_loss: 0.0266
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9787 - loss: 0.0799 - val_accuracy: 0.9931 - val_loss: 0.0295
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9824 - loss: 0.0659 - val_accuracy: 0.9971 - val_loss: 0.0161
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9857 - loss: 0.0535 - val_accuracy: 0.9967 - val_loss: 0.0141
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9856 - loss: 0.0510 - val_accuracy: 0.9972 - val_loss: 0.0095
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9825 - loss: 0.0621 - val_accuracy: 0.9885 - val_loss: 0.0740
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9807 - loss: 0.0697 - val_accuracy: 0.9962 - val_loss: 0.0139
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9861 - loss: 0.0469 - val_accuracy: 0.9951 - val_loss: 0.0173
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9884 - loss: 0.0429 - val_accuracy: 0.9967 - val_loss: 0.0270
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9879 - loss: 0.0459 - val_accuracy: 0.9994 - val_loss: 0.0022
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9873 - loss: 0.0425 - val_accuracy: 0.9971 - val_loss: 0.0125
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9844 - loss: 0.0593 - val_accuracy: 0.9979 - val_loss: 0.0074
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9824 - loss: 0.0672 - val_accuracy: 0.9947 - val_loss: 0.0187
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9838 - loss: 0.0578 - val_accuracy: 0.9973 - val_loss: 0.0095
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9852 - loss: 0.0548 - val_accuracy: 0.9974 - val_loss: 0.0105
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9860 - loss: 0.0517 - val_accuracy: 0.9964 - val_loss: 0.0129
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9877 - loss: 0.0455 - val_accuracy: 0.9974 - val_loss: 0.0197
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9863 - loss: 0.0524 - val_accuracy: 0.9987 - val_loss: 0.0048
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9884 - loss: 0.0413 - val_accuracy: 0.9986 - val_loss: 0.0046
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9856 - loss: 0.0549 - val_accuracy: 0.9967 - val_loss: 0.0126
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9876 - loss: 0.0482 - val_accuracy: 0.9971 - val_loss: 0.0126
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9909 - loss: 0.0359 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9908 - loss: 0.0321 - val_accuracy: 0.9982 - val_loss: 0.0092
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9881 - loss: 0.0452 - val_accuracy: 0.9978 - val_loss: 0.0069
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9854 - loss: 0.0514 - val_accuracy: 0.9970 - val_loss: 0.0103
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9884 - loss: 0.0477 - val_accuracy: 0.9973 - val_loss: 0.0083
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9908 - loss: 0.0393 - val_accuracy: 0.9978 - val_loss: 0.0085
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9880 - loss: 0.0510 - val_accuracy: 0.9953 - val_loss: 0.0179
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9847 - loss: 0.0686 - val_accuracy: 0.9972 - val_loss: 0.0104
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9893 - loss: 0.0409 - val_accuracy: 0.9981 - val_loss: 0.0066
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9907 - loss: 0.0377 - val_accuracy: 0.9977 - val_loss: 0.0065
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9948 - loss: 0.0206 - val_accuracy: 0.9991 - val_loss: 0.0033
# 2025-10-26 20:24:55.041773: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1687', 16 bytes spill stores, 16 bytes spill loads
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# ---------------------------------------------------------------------
# 🔹 Save the Trained Model (Modern .keras format)
# ---------------------------------------------------------------------
model_filename = "cifar100_resnet50_model.keras"
trained_model.save(model_filename)
print(f"✅ Model saved as {model_filename}")

# ---------------------------------------------------------------------
# 🔹 CIFAR-100 Label Names (Human-Readable)
# ---------------------------------------------------------------------
cifar100_label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

# ---------------------------------------------------------------------
# 🔹 Display 50 Random Predictions vs True Labels
# ---------------------------------------------------------------------
num_samples = 50
indices = random.sample(range(len(final_x_test)), num_samples)

y_true = np.argmax(final_y_test, axis=1)
y_pred = np.argmax(trained_model.predict(final_x_test), axis=1)

plt.figure(figsize=(15, 15))
for i, idx in enumerate(indices):
    image = final_x_test[idx]
    true_label = cifar100_label_names[y_true[idx]]
    predicted_label = cifar100_label_names[y_pred[idx]]

    plt.subplot(10, 5, i + 1)
    plt.imshow(image)
    plt.axis("off")
    color = "green" if true_label == predicted_label else "red"
    plt.title(f"True: {true_label}\nPred: {predicted_label}", color=color)

plt.tight_layout()
plt.show()

# ---------------------------------------------------------------------
# 🔹 Confusion Matrix (subset of 5000 test samples)
# ---------------------------------------------------------------------
num_test_samples = 5000
random_indices = np.random.choice(len(final_x_test), num_test_samples, replace=False)

x_test_subset = final_x_test[random_indices]
y_test_subset = np.argmax(final_y_test[random_indices], axis=1)
y_pred_subset = np.argmax(trained_model.predict(x_test_subset), axis=1)

cm = confusion_matrix(y_test_subset, y_pred_subset, labels=np.arange(100))
cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(15, 12))
sns.heatmap(cm_normalized, annot=False, fmt=".2f", cmap="Blues")
plt.title("Final Normalized Confusion Matrix (CIFAR-100, 5000 Samples)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# ✅ Model saved as cifar100_resnet50_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 151/157 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2025-10-26 20:25:11.432561: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1687', 8 bytes spill stores, 8 bytes spill loads
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step
